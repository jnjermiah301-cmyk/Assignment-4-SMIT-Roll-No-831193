# %% [markdown]
# # **Movie Dataset Python Assignment**

# %% [markdown]
# ### **Question 1**
# Dataset (`movie.csv`) ko pandas mein load karein aur uske pehle 5 rows display karein.

# %%
import pandas as pd
Dataset = pd.read_csv("movie.csv")
Dataset
# Out:
#                  Series_Title Released_Year Certificate  Runtime  \
# 0    The Shawshank Redemption          1994           A  142 min
# 1               The Godfather          1972           A  175 min
# 2             The Dark Knight          2008          UA  152 min
# 3      The Godfather: Part II          1974           A  202 min
# 4                12 Angry Men          1957           U   96 min
# ..                        ...           ...         ...      ...
# 995    Breakfast at Tiffany's          1961           A  115 min
# 996                     Giant          1956           G  201 min
# 997     From Here to Eternity          1953      Passed  118 min
# 998                  Lifeboat          1944         NaN   97 min
# 999              The 39 Steps          1935         NaN   86 min
#
#                         Genre  IMDB_Rating  Meta_score              Director  \
# 0                       Drama          9.3        80.0        Frank Darabont
# 1                Crime, Drama          9.2       100.0  Francis Ford Coppola
# 2        Action, Crime, Drama          9.0        84.0     Christopher Nolan
# 3                Crime, Drama          9.0        90.0  Francis Ford Coppola
# 4                Crime, Drama          9.0        96.0          Sidney Lumet
# ..                        ...          ...         ...                   ...
# 995    Comedy, Drama, Romance          7.6        76.0         Blake Edwards
# 996            Drama, Western          7.6        84.0        George Stevens
# 997       Drama, Romance, War          7.6        85.0        Fred Zinnemann
# 998                Drama, War          7.6        78.0      Alfred Hitchcock
# 999  Crime, Mystery, Thriller          7.6        93.0      Alfred Hitchcock
#
#                  Star1  No_of_Votes        Gross
# 0          Tim Robbins      2343110   28341469.0
# 1        Marlon Brando      1620367  134966411.0
# 2       Christian Bale      2303232  534858444.0
# 3            Al Pacino      1129952   57300000.0
# 4          Henry Fonda       689845    4360000.0
# ..                 ...          ...          ...
# 995     Audrey Hepburn       166544          NaN
# 996   Elizabeth Taylor        34075          NaN
# 997     Burt Lancaster        43374   30500000.0
# 998  Tallulah Bankhead        26471          NaN
# 999       Robert Donat        51853          NaN
#
# [1000 rows x 11 columns]

# %%
Dataset.head()
# Out:
#                Series_Title Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption          1994           A  142 min
# 1             The Godfather          1972           A  175 min
# 2           The Dark Knight          2008          UA  152 min
# 3    The Godfather: Part II          1974           A  202 min
# 4              12 Angry Men          1957           U   96 min
#
#                   Genre  IMDB_Rating  Meta_score              Director  \
# 0                 Drama          9.3        80.0        Frank Darabont
# 1          Crime, Drama          9.2       100.0  Francis Ford Coppola
# 2  Action, Crime, Drama          9.0        84.0     Christopher Nolan
# 3          Crime, Drama          9.0        90.0  Francis Ford Coppola
# 4          Crime, Drama          9.0        96.0          Sidney Lumet
#
#             Star1  No_of_Votes        Gross
# 0     Tim Robbins      2343110   28341469.0
# 1   Marlon Brando      1620367  134966411.0
# 2  Christian Bale      2303232  534858444.0
# 3       Al Pacino      1129952   57300000.0
# 4     Henry Fonda       689845    4360000.0

# %% [markdown]
# ### **Question 2**
# Dataset ka total shape (rows aur columns count) check karke print karein.

# %%
Dataset.shape
# Out:
# (1000, 11)

# %% [markdown]
# ### **Question 3**
# Check karein ki kis kis column mein missing values (null values) hain aur unka exact count kya hai.

# %%
Dataset.isna().sum()
# Out:
# Series_Title       0
# Released_Year      0
# Certificate      101
# Runtime            0
# Genre              0
# IMDB_Rating        0
# Meta_score       157
# Director           0
# Star1              0
# No_of_Votes        0
# Gross            169
# dtype: int64

# %% [markdown]
# ### **Question 4**
# Which movies were released after the year 2000? (Year 2000 ke baad release hone wali movies filter karein).

# %%
Dataset2 = Dataset.drop(Dataset[Dataset.Released_Year == "PG"].index)

# %%
Dataset2.Released_Year.unique()
# Out:
# array(['1994', '1972', '2008', '1974', '1957', '2003', '1993', '2010',
#        '1999', '2001', '1966', '2002', '1990', '1980', '1975', '2020',
#        '2019', '2014', '1998', '1997', '1995', '1991', '1977', '1962',
#        '1954', '1946', '2011', '2006', '2000', '1988', '1985', '1968',
#        '1960', '1942', '1936', '1931', '2018', '2017', '2016', '2012',
#        '2009', '2007', '1984', '1981', '1979', '1971', '1963', '1964',
#        '1950', '1940', '2013', '2005', '2004', '1992', '1987', '1986',
#        '1983', '1976', '1973', '1965', '1959', '1958', '1952', '1948',
#        '1944', '1941', '1927', '1921', '2015', '1996', '1989', '1978',
#        '1961', '1955', '1953', '1925', '1924', '1982', '1967', '1951',
#        '1949', '1939', '1937', '1934', '1928', '1926', '1920', '1970',
#        '1969', '1956', '1947', '1945', '1930', '1938', '1935', '1933',
#        '1932', '1922', '1943'], dtype=object)

# %%
Dataset2.Released_Year
# Out:
# 0      1994
# 1      1972
# 2      2008
# 3      1974
# 4      1957
#        ...
# 995    1961
# 996    1956
# 997    1953
# 998    1944
# 999    1935
# Name: Released_Year, Length: 999, dtype: object

# %%
Dataset2.Released_Year = Dataset2.Released_Year.astype(int)

# %%
movies = Dataset2[Dataset2["Released_Year"] > 2000]
movies
# Out:
#                                           Series_Title  Released_Year  \
# 2                                      The Dark Knight           2008
# 5        The Lord of the Rings: The Return of the King           2003
# 8                                            Inception           2010
# 10   The Lord of the Rings: The Fellowship of the Ring           2001
# 13               The Lord of the Rings: The Two Towers           2002
# ..                                                 ...            ...
# 947              Harry Potter and the Sorcerer's Stone           2001
# 948                                         The Others           2001
# 949                                               Blow           2001
# 950                                 Enemy at the Gates           2001
# 951                                    Minority Report           2002
#
#     Certificate  Runtime                       Genre  IMDB_Rating  Meta_score  \
# 2            UA  152 min        Action, Crime, Drama          9.0        84.0
# 5             U  201 min    Action, Adventure, Drama          8.9        94.0
# 8            UA  148 min   Action, Adventure, Sci-Fi          8.8        74.0
# 10            U  178 min    Action, Adventure, Drama          8.8        92.0
# 13           UA  179 min    Action, Adventure, Drama          8.7        87.0
# ..          ...      ...                         ...          ...         ...
# 947           U  152 min  Adventure, Family, Fantasy          7.6        64.0
# 948       PG-13  101 min   Horror, Mystery, Thriller          7.6        74.0
# 949           R  124 min     Biography, Crime, Drama          7.6        52.0
# 950           A  131 min         Drama, History, War          7.6        53.0
# 951           A  145 min      Action, Crime, Mystery          7.6        80.0
#
#                 Director              Star1  No_of_Votes        Gross
# 2      Christopher Nolan     Christian Bale      2303232  534858444.0
# 5          Peter Jackson        Elijah Wood      1642758  377845905.0
# 8      Christopher Nolan  Leonardo DiCaprio      2067042  292576195.0
# 10         Peter Jackson        Elijah Wood      1661481  315544750.0
# 13         Peter Jackson        Elijah Wood      1485555  342551365.0
# ..                   ...                ...          ...          ...
# 947       Chris Columbus   Daniel Radcliffe       658185  317575550.0
# 948   Alejandro Amenábar      Nicole Kidman       337651   96522687.0
# 949            Ted Demme        Johnny Depp       240714   52990775.0
# 950  Jean-Jacques Annaud           Jude Law       243729   51401758.0
# 951     Steven Spielberg         Tom Cruise       508417  132072926.0
#
# [466 rows x 11 columns]

# %% [markdown]
# ### **Question 5**
# Which movies have an IMDB rating greater than 9? (9 se zyada IMDB rating wali movies display karein).

# %%
movies = Dataset2[Dataset2["IMDB_Rating"] > 9]

# %%
movies
# Out:
#                Series_Title  Released_Year Certificate  Runtime         Genre  \
# 0  The Shawshank Redemption           1994           A  142 min         Drama
# 1             The Godfather           1972           A  175 min  Crime, Drama
#
#    IMDB_Rating  Meta_score              Director          Star1  No_of_Votes  \
# 0          9.3        80.0        Frank Darabont    Tim Robbins      2343110
# 1          9.2       100.0  Francis Ford Coppola  Marlon Brando      1620367
#
#          Gross
# 0   28341469.0
# 1  134966411.0

# %% [markdown]
# ### **Question 6**
# How many movies are there for each genre? (Har genre ki total kitni movies hain, count nikalye).

# %%
total_genre = Dataset2['Genre'].value_counts()
total_genre
# Out:
# Genre
# Drama                        75
# Drama, Romance               31
# Comedy, Drama                29
# Comedy, Drama, Romance       26
# Crime, Drama, Thriller       25
#                              ..
# Drama, History                1
# Film-Noir, Mystery            1
# Drama, Film-Noir, Mystery     1
# Adventure, Thriller           1
# Adventure, Comedy, War        1
# Name: count, Length: 182, dtype: int64

# %% [markdown]
# ### **Question 7**
# Which movies were directed by Christopher Nolan? (Christopher Nolan ki directed saari movies nikalye).

# %%
movies = Dataset2[Dataset2['Director'] == 'Christopher Nolan']
movies
# Out:
#               Series_Title  Released_Year Certificate  Runtime  \
# 2          The Dark Knight           2008          UA  152 min
# 8                Inception           2010          UA  148 min
# 21            Interstellar           2014          UA  169 min
# 36            The Prestige           2006           U  130 min
# 63   The Dark Knight Rises           2012          UA  164 min
# 69                 Memento           2000          UA  113 min
# 155          Batman Begins           2005          UA  140 min
# 573                Dunkirk           2017          UA  106 min
#
#                          Genre  IMDB_Rating  Meta_score           Director  \
# 2         Action, Crime, Drama          9.0        84.0  Christopher Nolan
# 8    Action, Adventure, Sci-Fi          8.8        74.0  Christopher Nolan
# 21    Adventure, Drama, Sci-Fi          8.6        74.0  Christopher Nolan
# 36      Drama, Mystery, Sci-Fi          8.5        66.0  Christopher Nolan
# 63           Action, Adventure          8.4        78.0  Christopher Nolan
# 69           Mystery, Thriller          8.4        80.0  Christopher Nolan
# 155          Action, Adventure          8.2        70.0  Christopher Nolan
# 573     Action, Drama, History          7.8        94.0  Christopher Nolan
#
#                    Star1  No_of_Votes        Gross
# 2         Christian Bale      2303232  534858444.0
# 8      Leonardo DiCaprio      2067042  292576195.0
# 21   Matthew McConaughey      1512360  188020017.0
# 36        Christian Bale      1190259   53089891.0
# 63        Christian Bale      1516346  448139099.0
# 69            Guy Pearce      1125712   25544867.0
# 155       Christian Bale      1308302  206852432.0
# 573      Fionn Whitehead       555092  188373161.0

# %% [markdown]
# ### **Question 8**
# Which movies have 'Drama' mentioned in their genre? ('Drama' genre wali movies ko filter karein).

# %%
drama_movies = Dataset2[Dataset2['Genre'].str.contains('Drama', case=False, na=False)]
drama_movies
# Out:
#                  Series_Title  Released_Year Certificate  Runtime  \
# 0    The Shawshank Redemption           1994           A  142 min
# 1               The Godfather           1972           A  175 min
# 2             The Dark Knight           2008          UA  152 min
# 3      The Godfather: Part II           1974           A  202 min
# 4                12 Angry Men           1957           U   96 min
# ..                        ...            ...         ...      ...
# 993                    Blowup           1966           A  111 min
# 995    Breakfast at Tiffany's           1961           A  115 min
# 996                     Giant           1956           G  201 min
# 997     From Here to Eternity           1953      Passed  118 min
# 998                  Lifeboat           1944         NaN   97 min
#
#                         Genre  IMDB_Rating  Meta_score  \
# 0                       Drama          9.3        80.0
# 1                Crime, Drama          9.2       100.0
# 2        Action, Crime, Drama          9.0        84.0
# 3                Crime, Drama          9.0        90.0
# 4                Crime, Drama          9.0        96.0
# ..                        ...          ...         ...
# 993  Drama, Mystery, Thriller          7.6        82.0
# 995    Comedy, Drama, Romance          7.6        76.0
# 996            Drama, Western          7.6        84.0
# 997       Drama, Romance, War          7.6        85.0
# 998                Drama, War          7.6        78.0
#
#                    Director              Star1  No_of_Votes        Gross
# 0            Frank Darabont        Tim Robbins      2343110   28341469.0
# 1      Francis Ford Coppola      Marlon Brando      1620367  134966411.0
# 2         Christopher Nolan     Christian Bale      2303232  534858444.0
# 3      Francis Ford Coppola          Al Pacino      1129952   57300000.0
# 4              Sidney Lumet        Henry Fonda       689845    4360000.0
# ..                      ...                ...          ...          ...
# 993  Michelangelo Antonioni     David Hemmings        56513          NaN
# 995           Blake Edwards     Audrey Hepburn       166544          NaN
# 996          George Stevens   Elizabeth Taylor        34075          NaN
# 997          Fred Zinnemann     Burt Lancaster        43374   30500000.0
# 998        Alfred Hitchcock  Tallulah Bankhead        26471          NaN
#
# [723 rows x 11 columns]

# %% [markdown]
# ### **Question 9**
# How can we sort all movies by IMDB rating in descending order? (Movies ko highest se lowest rating ke mutabiq sort karein).

# %%
movies = Dataset2.sort_values(by='IMDB_Rating', ascending=False, na_position='last')
movies
# Out:
#                  Series_Title  Released_Year Certificate  Runtime  \
# 0    The Shawshank Redemption           1994           A  142 min
# 1               The Godfather           1972           A  175 min
# 2             The Dark Knight           2008          UA  152 min
# 3      The Godfather: Part II           1974           A  202 min
# 4                12 Angry Men           1957           U   96 min
# ..                        ...            ...         ...      ...
# 912                Zombieland           2009           A   88 min
# 911        La piel que habito           2011           R  120 min
# 910                 Moneyball           2011       PG-13  133 min
# 909                 Celda 211           2009         NaN  113 min
# 999              The 39 Steps           1935         NaN   86 min
#
#                           Genre  IMDB_Rating  Meta_score  \
# 0                         Drama          9.3        80.0
# 1                  Crime, Drama          9.2       100.0
# 2          Action, Crime, Drama          9.0        84.0
# 3                  Crime, Drama          9.0        90.0
# 4                  Crime, Drama          9.0        96.0
# ..                          ...          ...         ...
# 912  Adventure, Comedy, Fantasy          7.6        73.0
# 911     Drama, Horror, Thriller          7.6        70.0
# 910     Biography, Drama, Sport          7.6        87.0
# 909    Action, Adventure, Crime          7.6         NaN
# 999    Crime, Mystery, Thriller          7.6        93.0
#
#                  Director             Star1  No_of_Votes        Gross
# 0          Frank Darabont       Tim Robbins      2343110   28341469.0
# 1    Francis Ford Coppola     Marlon Brando      1620367  134966411.0
# 2       Christopher Nolan    Christian Bale      2303232  534858444.0
# 3    Francis Ford Coppola         Al Pacino      1129952   57300000.0
# 4            Sidney Lumet       Henry Fonda       689845    4360000.0
# ..                    ...               ...          ...          ...
# 912       Ruben Fleischer   Jesse Eisenberg       520041   75590286.0
# 911       Pedro Almodóvar  Antonio Banderas       138959    3185812.0
# 910        Bennett Miller         Brad Pitt       369529   75605492.0
# 909         Daniel Monzón        Luis Tosar        63882          NaN
# 999      Alfred Hitchcock      Robert Donat        51853          NaN
#
# [999 rows x 11 columns]

# %% [markdown]
# ### **Question 10**
# How can we sort all movies by the number of votes they received? (No_of_Votes ke mutabiq descending order mein sort karein).

# %%
movies = Dataset2.sort_values(by='No_of_Votes', ascending=False, na_position='last')
movies
# Out:
#                           Series_Title  Released_Year Certificate  Runtime  \
# 0             The Shawshank Redemption           1994           A  142 min
# 2                      The Dark Knight           2008          UA  152 min
# 8                            Inception           2010          UA  148 min
# 9                           Fight Club           1999           A  139 min
# 6                         Pulp Fiction           1994           A  154 min
# ..                                 ...            ...         ...      ...
# 570                              Raazi           2018          UA  138 min
# 718  Scarface: The Shame of the Nation           1932          PG   93 min
# 694                 La planète sauvage           1973           U   72 min
# 721                  God's Own Country           2017         NaN  104 min
# 264                     Ba wang bie ji           1993           R  171 min
#
#                          Genre  IMDB_Rating  Meta_score           Director  \
# 0                        Drama          9.3        80.0     Frank Darabont
# 2         Action, Crime, Drama          9.0        84.0  Christopher Nolan
# 8    Action, Adventure, Sci-Fi          8.8        74.0  Christopher Nolan
# 9                        Drama          8.8        66.0      David Fincher
# 6                 Crime, Drama          8.9        94.0  Quentin Tarantino
# ..                         ...          ...         ...                ...
# 570    Action, Drama, Thriller          7.8         NaN      Meghna Gulzar
# 718       Action, Crime, Drama          7.8        87.0       Howard Hawks
# 694          Animation, Sci-Fi          7.8        73.0        René Laloux
# 721             Drama, Romance          7.7        85.0        Francis Lee
# 264      Drama, Music, Romance          8.1         NaN         Kaige Chen
#
#                  Star1  No_of_Votes        Gross
# 0          Tim Robbins      2343110   28341469.0
# 2       Christian Bale      2303232  534858444.0
# 8    Leonardo DiCaprio      2067042  292576195.0
# 9            Brad Pitt      1854740   37030102.0
# 6        John Travolta      1826188  107928762.0
# ..                 ...          ...          ...
# 570         Alia Bhatt        25344          NaN
# 718     Richard Rosson        25312          NaN
# 694     Barry Bostwick        25229     193817.0
# 721      Josh O'Connor        25198     335609.0
# 264      Leslie Cheung        25088    5216888.0
#
# [999 rows x 11 columns]

# %% [markdown]
# ### **Question 11**
# Which movie has the longest runtime? (Sabse lambi movie ka naam aur runtime minutes mein nikalye).

# %%
movie = Dataset2[Dataset2['Runtime'] == Dataset['Runtime'].max()]
movie[['Series_Title', 'Runtime']]
# Out:
#                    Series_Title Runtime
# 103              Reservoir Dogs  99 min
# 175                 Höstsonaten  99 min
# 192          To Be or Not to Be  99 min
# 209    The Grand Budapest Hotel  99 min
# 260       Trois couleurs: Rouge  99 min
# 299      Les quatre cents coups  99 min
# 311  The Shop Around the Corner  99 min
# 431     Per un pugno di dollari  99 min
# 503           Shaun of the Dead  99 min
# 643                 Waking Life  99 min
# 776                     Kung fu  99 min
# 814               Do lok tin si  99 min
# 972                Delicatessen  99 min
# 980                Blood Simple  99 min

# %% [markdown]
# ### **Question 12**
# Which movies have Leonardo DiCaprio listed as the first star (Star1)?

# %%
movies = Dataset[Dataset['Star1'] == 'Leonardo DiCaprio']
movies
# Out:
#                          Series_Title Released_Year Certificate  Runtime  \
# 8                           Inception          2010          UA  148 min
# 37                       The Departed          2006           A  151 min
# 145                    Shutter Island          2010           A  138 min
# 147           The Wolf of Wall Street          2013           A  180 min
# 243               Catch Me If You Can          2002           A  141 min
# 343                      The Revenant          2015           A  156 min
# 361                     Blood Diamond          2006           A  143 min
# 652                           Titanic          1997          UA  194 min
# 879  Once Upon a Time... in Hollywood          2019           A  161 min
#
#                           Genre  IMDB_Rating  Meta_score  \
# 8     Action, Adventure, Sci-Fi          8.8        74.0
# 37       Crime, Drama, Thriller          8.5        85.0
# 145           Mystery, Thriller          8.2        63.0
# 147     Biography, Crime, Drama          8.2        75.0
# 243     Biography, Crime, Drama          8.1        75.0
# 343    Action, Adventure, Drama          8.0        76.0
# 361  Adventure, Drama, Thriller          8.0        64.0
# 652              Drama, Romance          7.8        75.0
# 879               Comedy, Drama          7.6        83.0
#
#                   Director              Star1  No_of_Votes        Gross
# 8        Christopher Nolan  Leonardo DiCaprio      2067042  292576195.0
# 37         Martin Scorsese  Leonardo DiCaprio      1189773  132384315.0
# 145        Martin Scorsese  Leonardo DiCaprio      1129894  128012934.0
# 147        Martin Scorsese  Leonardo DiCaprio      1187498  116900694.0
# 243       Steven Spielberg  Leonardo DiCaprio       832846  164615351.0
# 343  Alejandro G. Iñárritu  Leonardo DiCaprio       705589  183637894.0
# 361           Edward Zwick  Leonardo DiCaprio       499439   57366262.0
# 652          James Cameron  Leonardo DiCaprio      1046089  659325379.0
# 879      Quentin Tarantino  Leonardo DiCaprio       551309  142502728.0

# %% [markdown]
# ### **Question 13**
# What is the average IMDB rating of all movies? (Saari movies ki average rating calculate karein).

# %%
average = Dataset2['IMDB_Rating'].mean()
average
# Out:
# np.float64(7.9496496496496505)

# %% [markdown]
# ### **Question 14**
# Dataset ka poora statistical summary (`describe()` function) display karein.

# %%
Dataset2.describe()
# Out:
#        Released_Year  IMDB_Rating  Meta_score   No_of_Votes         Gross
# count     999.000000   999.000000  842.000000  9.990000e+02  8.300000e+02
# mean     1991.217217     7.949650   77.972684  2.736974e+05  6.790728e+07
# std        23.297025     0.275407   12.383410  3.275366e+05  1.097546e+08
# min      1920.000000     7.600000   28.000000  2.508800e+04  1.305000e+03
# 25%      1976.000000     7.700000   70.000000  5.547150e+04  3.245338e+06
# 50%      1999.000000     7.900000   79.000000  1.383560e+05  2.345744e+07
# 75%      2009.000000     8.100000   87.000000  3.744775e+05  8.010324e+07
# max      2020.000000     9.300000  100.000000  2.343110e+06  9.366622e+08

# %% [markdown]
# ### **Question 15**
# 'Runtime' column se 'min' text ko hata kar use proper integer (numeric) data type mein convert karein.

# %%
Dataset = Dataset2.Runtime.replace('min','')
Dataset
# Out:
# 0      142 min
# 1      175 min
# 2      152 min
# 3      202 min
# 4       96 min
#         ...
# 995    115 min
# 996    201 min
# 997    118 min
# 998     97 min
# 999     86 min
# Name: Runtime, Length: 999, dtype: object

# %% [markdown]
# ### **Question 16**
# 'Gross' column mein jo missing values (NaN) hain, unko pooray column ke median value se fill (impute) karein.

# %%
Dataset2 = Dataset2.dropna(subset=['Gross'])
Dataset2
# Out:
#                  Series_Title  Released_Year Certificate  Runtime  \
# 0    The Shawshank Redemption           1994           A  142 min
# 1               The Godfather           1972           A  175 min
# 2             The Dark Knight           2008          UA  152 min
# 3      The Godfather: Part II           1974           A  202 min
# 4                12 Angry Men           1957           U   96 min
# ..                        ...            ...         ...      ...
# 990              Giù la testa           1971          PG  157 min
# 991            Kelly's Heroes           1970          GP  144 min
# 992           The Jungle Book           1967           U   78 min
# 994        A Hard Day's Night           1964           U   87 min
# 997     From Here to Eternity           1953      Passed  118 min
#
#                             Genre  IMDB_Rating  Meta_score  \
# 0                           Drama          9.3        80.0
# 1                    Crime, Drama          9.2       100.0
# 2            Action, Crime, Drama          9.0        84.0
# 3                    Crime, Drama          9.0        90.0
# 4                    Crime, Drama          9.0        96.0
# ..                            ...          ...         ...
# 990           Drama, War, Western          7.6        77.0
# 991        Adventure, Comedy, War          7.6        50.0
# 992  Animation, Adventure, Family          7.6        65.0
# 994        Comedy, Music, Musical          7.6        96.0
# 997           Drama, Romance, War          7.6        85.0
#
#                  Director           Star1  No_of_Votes        Gross
# 0          Frank Darabont     Tim Robbins      2343110   28341469.0
# 1    Francis Ford Coppola   Marlon Brando      1620367  134966411.0
# 2       Christopher Nolan  Christian Bale      2303232  534858444.0
# 3    Francis Ford Coppola       Al Pacino      1129952   57300000.0
# 4            Sidney Lumet     Henry Fonda       689845    4360000.0
# ..                    ...             ...          ...          ...
# 990          Sergio Leone     Rod Steiger        30144     696690.0
# 991       Brian G. Hutton  Clint Eastwood        45338    1378435.0
# 992   Wolfgang Reitherman     Phil Harris       166409  141843612.0
# 994        Richard Lester     John Lennon        40351   13780024.0
# 997        Fred Zinnemann  Burt Lancaster        43374   30500000.0
#
# [830 rows x 11 columns]

# %% [markdown]
# ### **Question 17**
# Har 'Certificate' category mein total kitni movies hain? (Value counts nikalye).

# %%
certificate = Dataset2['Certificate'].value_counts()
certificate
# Out:
# Certificate
# U           199
# A           180
# UA          163
# R           135
# PG-13        39
# PG           24
# Passed       23
# G            10
# Approved      6
# GP            2
# Unrated       1
# TV-PG         1
# U/A           1
# Name: count, dtype: int64

# %% [markdown]
# ### **Question 18**
# 'IMDB_Rating' aur 'Meta_score' ke darmiyan correlation coefficient maloom karein.

# %%
Dataset = Dataset2.dropna(subset=['IMDB_Rating', 'Meta_score'])
print(Dataset['IMDB_Rating'].corr(Dataset['Meta_score']))
# Out:
# 0.2828867370773465

# %% [markdown]
# ### **Question 19**
# Ek naya column banayein 'Rating_100_Scale' jisme 'IMDB_Rating' ko 10 se multiply kiya gaya ho.

# %%
Dataset['Rating_100_Scale'] = Dataset['IMDB_Rating'] * 10
# Out:
# C:\Users\khanb\AppData\Local\Temp\ipykernel_15224\246707555.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Dataset['Rating_100_Scale'] = Dataset['IMDB_Rating'] * 10

# %% [markdown]
# ### **Question 20**
# Year 1990 se 2000 (both inclusive) ke darmiyan release hone wali movies ki total count aur list nikaleyin.

# %%
movies = Dataset[(Dataset['Released_Year'] >= 1990) & (Dataset['Released_Year'] <= 2000)]
total_movies = len(movies)
total_movies
# Out:
# 146

# %% [markdown]
# ### **Question 21**
# (Visualization) IMDB_Rating ka distribution dekhne ke liye ek neat Histogram plot karein.

# %%
import matplotlib.pyplot as plt
plt.hist(Dataset['IMDB_Rating'], bins=15, edgecolor='black')
plt.xlabel('IMDB Rating')
plt.ylabel('Count')
plt.title('IMDB Rating Distribution')
plt.show()

# %% [markdown]
# ### **Question 22**
# (Visualization) Top 10 Directors aur unki total movies ka ek attractive Bar Chart banayein.

# %%
import matplotlib.pyplot as plt
top_directors = Dataset['Director'].value_counts().head(10)
plt.barh(top_directors.index, top_directors.values)
plt.xlabel('Number of Movies')
plt.title('Top 10 Directors')
plt.show()

# %% [markdown]
# ### **Question 23**
# (Visualization) IMDB_Rating aur Gross revenue ke darmiyan ek Scatter Plot banayein taake dono ka relation dikhe.

# %%
import matplotlib.pyplot as plt
plt.scatter(Dataset['IMDB_Rating'], Dataset['Gross'])
plt.title('IMDB Rating vs Gross')
plt.show()

# %% [markdown]
# ### **Question 24**
# (Visualization) Genres ka count dekhne ke liye top 5 genres ka ek clean Pie Chart banayein.

# %%
import matplotlib.pyplot as plt
top_genres = Dataset['Genre'].value_counts().head(5)
plt.pie(top_genres, labels=top_genres.index)
plt.show()

# %% [markdown]
# ### **Question 25**
# (Visualization) Meta_score ka distribution aur outliers check karne ke liye ek Box Plot banayein.

# %%
import matplotlib.pyplot as plt
plt.boxplot(Dataset['Meta_score'].dropna())
plt.title('Meta Score Box Plot')
plt.show()

# %% [markdown]
# ### **Question 26**
# (Visualization) Dataset mein 'Certificate' wise average 'Gross' kamai ka ek Bar Plot banayein.

# %%
import matplotlib.pyplot as plt
Dataset.groupby('Certificate')['Gross'].mean().plot(kind='bar')
plt.show()

# %% [markdown]
# ### **Question 27**
# (Visualization) Har saal (Released_Year) kitni movies release hueen, iska ek Line Plot banayein.

# %%
import matplotlib.pyplot as plt
yearly_data = Dataset['Released_Year'].value_counts().sort_index()
plt.plot(yearly_data)
plt.show()

# %% [markdown]
# ### **Question 28**
# (Visualization) 'No_of_Votes' ke mutabiq top 5 highest voted movies ka ek Horizontal Bar Chart banayein.

# %%
import matplotlib.pyplot as plt
top_5_votes = Dataset.nlargest(5, 'No_of_Votes')
plt.barh(top_5_votes['Series_Title'], top_5_votes['No_of_Votes'])
plt.show()

# %% [markdown]
# ### **Question 29**
# Har movie ke 'Genre' column ko split karke check karein ki total unique genres pure dataset mein kitne hain.

# %%
count_genres = Dataset['Genre'].str.split(', ').explode().nunique()
print(count_genres)
# Out:
# 21

# %% [markdown]
# ### **Question 30**
# Dataset ko poora clean karne ke baad safely ek nayi csv file 'cleaned_movies.csv' ke naam se save karein.

# %%
Dataset = Dataset.dropna()
Dataset.to_csv('cleaned_movies.csv', index=False)
Dataset
# Out:
#                  Series_Title  Released_Year Certificate  Runtime  \
# 0    The Shawshank Redemption           1994           A  142 min
# 1               The Godfather           1972           A  175 min
# 2             The Dark Knight           2008          UA  152 min
# 3      The Godfather: Part II           1974           A  202 min
# 4                12 Angry Men           1957           U   96 min
# ..                        ...            ...         ...      ...
# 990              Giù la testa           1971          PG  157 min
# 991            Kelly's Heroes           1970          GP  144 min
# 992           The Jungle Book           1967           U   78 min
# 994        A Hard Day's Night           1964           U   87 min
# 997     From Here to Eternity           1953      Passed  118 min
#
#                             Genre  IMDB_Rating  Meta_score  \
# 0                           Drama          9.3        80.0
# 1                    Crime, Drama          9.2       100.0
# 2            Action, Crime, Drama          9.0        84.0
# 3                    Crime, Drama          9.0        90.0
# 4                    Crime, Drama          9.0        96.0
# ..                            ...          ...         ...
# 990           Drama, War, Western          7.6        77.0
# 991        Adventure, Comedy, War          7.6        50.0
# 992  Animation, Adventure, Family          7.6        65.0
# 994        Comedy, Music, Musical          7.6        96.0
# 997           Drama, Romance, War          7.6        85.0
#
#                  Director           Star1  No_of_Votes        Gross  \
# 0          Frank Darabont     Tim Robbins      2343110   28341469.0
# 1    Francis Ford Coppola   Marlon Brando      1620367  134966411.0
# 2       Christopher Nolan  Christian Bale      2303232  534858444.0
# 3    Francis Ford Coppola       Al Pacino      1129952   57300000.0
# 4            Sidney Lumet     Henry Fonda       689845    4360000.0
# ..                    ...             ...          ...          ...
# 990          Sergio Leone     Rod Steiger        30144     696690.0
# 991       Brian G. Hutton  Clint Eastwood        45338    1378435.0
# 992   Wolfgang Reitherman     Phil Harris       166409  141843612.0
# 994        Richard Lester     John Lennon        40351   13780024.0
# 997        Fred Zinnemann  Burt Lancaster        43374   30500000.0
#
#      Rating_100_Scale
# 0                93.0
# 1                92.0
# 2                90.0
# 3                90.0
# 4                90.0
# ..                ...
# 990              76.0
# 991              76.0
# 992              76.0
# 994              76.0
# 997              76.0
#
# [713 rows x 12 columns]

# %% [markdown]
# ### **Question 31**
# Kaunsi movies hain jinki 'IMDB_Rating' 8.5 se zyada hai AUR unka 'Gross' revenue 100 million (100,000,000) se zyada hai? (Dual condition filter)

# %%
grossing_dataset = Dataset[(Dataset['IMDB_Rating'] > 8.5) & (Dataset['Gross'] > 100000000)]
grossing_dataset
# Out:
#                                          Series_Title  Released_Year  \
# 1                                       The Godfather           1972
# 2                                     The Dark Knight           2008
# 5       The Lord of the Rings: The Return of the King           2003
# 6                                        Pulp Fiction           1994
# 8                                           Inception           2010
# 10  The Lord of the Rings: The Fellowship of the Ring           2001
# 11                                       Forrest Gump           1994
# 13              The Lord of the Rings: The Two Towers           2002
# 14                                         The Matrix           1999
# 16     Star Wars: Episode V - The Empire Strikes Back           1980
# 17                    One Flew Over the Cuckoo's Nest           1975
# 21                                       Interstellar           2014
# 24                                Saving Private Ryan           1998
# 25                                     The Green Mile           1999
# 27                                              Se7en           1995
# 28                           The Silence of the Lambs           1991
# 29                                          Star Wars           1977
#
#    Certificate  Runtime                       Genre  IMDB_Rating  Meta_score  \
# 1            A  175 min                Crime, Drama          9.2       100.0
# 2           UA  152 min        Action, Crime, Drama          9.0        84.0
# 5            U  201 min    Action, Adventure, Drama          8.9        94.0
# 6            A  154 min                Crime, Drama          8.9        94.0
# 8           UA  148 min   Action, Adventure, Sci-Fi          8.8        74.0
# 10           U  178 min    Action, Adventure, Drama          8.8        92.0
# 11          UA  142 min              Drama, Romance          8.8        82.0
# 13          UA  179 min    Action, Adventure, Drama          8.7        87.0
# 14           A  136 min              Action, Sci-Fi          8.7        73.0
# 16          UA  124 min  Action, Adventure, Fantasy          8.7        82.0
# 17           A  133 min                       Drama          8.7        83.0
# 21          UA  169 min    Adventure, Drama, Sci-Fi          8.6        74.0
# 24           R  169 min                  Drama, War          8.6        91.0
# 25           A  189 min       Crime, Drama, Fantasy          8.6        61.0
# 27           A  127 min       Crime, Drama, Mystery          8.6        65.0
# 28           A  118 min      Crime, Drama, Thriller          8.6        85.0
# 29          UA  121 min  Action, Adventure, Fantasy          8.6        90.0
#
#                 Director                Star1  No_of_Votes        Gross  \
# 1   Francis Ford Coppola        Marlon Brando      1620367  134966411.0
# 2      Christopher Nolan       Christian Bale      2303232  534858444.0
# 5          Peter Jackson          Elijah Wood      1642758  377845905.0
# 6      Quentin Tarantino        John Travolta      1826188  107928762.0
# 8      Christopher Nolan    Leonardo DiCaprio      2067042  292576195.0
# 10         Peter Jackson          Elijah Wood      1661481  315544750.0
# 11       Robert Zemeckis            Tom Hanks      1809221  330252182.0
# 13         Peter Jackson          Elijah Wood      1485555  342551365.0
# 14        Lana Wachowski      Lilly Wachowski      1676426  171479930.0
# 16        Irvin Kershner          Mark Hamill      1159315  290475067.0
# 17          Milos Forman       Jack Nicholson       918088  112000000.0
# 21     Christopher Nolan  Matthew McConaughey      1512360  188020017.0
# 24      Steven Spielberg            Tom Hanks      1235804  216540909.0
# 25        Frank Darabont            Tom Hanks      1147794  136801374.0
# 27         David Fincher       Morgan Freeman      1445096  100125643.0
# 28        Jonathan Demme         Jodie Foster      1270197  130742922.0
# 29          George Lucas          Mark Hamill      1231473  322740140.0
#
#     Rating_100_Scale
# 1               92.0
# 2               90.0
# 5               89.0
# 6               89.0
# 8               88.0
# 10              88.0
# 11              88.0
# 13              87.0
# 14              87.0
# 16              87.0
# 17              87.0
# 21              86.0
# 24              86.0
# 25              86.0
# 27              86.0
# 28              86.0
# 29              86.0

# %% [markdown]
# ### **Question 32**
# Director 'Christopher Nolan' ki un movies ke naam aur release year nikalein jinka 'Runtime' 140 minutes se zyada hai.

# %%
Dataset2['Runtime'] = Dataset2['Runtime'].str.replace(' min', '').str.strip().fillna(0).astype(int)

# %%
Dataset2['Runtime'] = Dataset2['Runtime']
Dataset2[(Dataset2['Director'] == 'Christopher Nolan') & (Dataset2['Runtime'] > 140)][['Series_Title', 'Runtime', 'Director', 'Released_Year']]
# Out:
#              Series_Title  Runtime           Director  Released_Year
# 2         The Dark Knight      152  Christopher Nolan           2008
# 8               Inception      148  Christopher Nolan           2010
# 21           Interstellar      169  Christopher Nolan           2014
# 63  The Dark Knight Rises      164  Christopher Nolan           2012

# %% [markdown]
# ### **Question 33**
# Aise actors (Star1) ki list nikalein jinhone 'Action' ya 'Sci-Fi' genre mein kaam kiya hai AUR unki movies ki 'IMDB_Rating' kam az kam 8.0 hai.

# %%
Dataset2[(Dataset2['Genre'].str.contains('Action|Sci-Fi')) & (Dataset2['IMDB_Rating'] >= 8.0)]
# Out:
#                                           Series_Title  Released_Year  \
# 2                                      The Dark Knight           2008
# 5        The Lord of the Rings: The Return of the King           2003
# 8                                            Inception           2010
# 10   The Lord of the Rings: The Fellowship of the Ring           2001
# 13               The Lord of the Rings: The Two Towers           2002
# ..                                                 ...            ...
# 405                                              Akira           1988
# 410                                     The Terminator           1984
# 426                                 Planet of the Apes           1968
# 431                            Per un pugno di dollari           1964
# 436                                          Rio Bravo           1959
#
#     Certificate  Runtime                      Genre  IMDB_Rating  Meta_score  \
# 2            UA      152       Action, Crime, Drama          9.0        84.0
# 5             U      201   Action, Adventure, Drama          8.9        94.0
# 8            UA      148  Action, Adventure, Sci-Fi          8.8        74.0
# 10            U      178   Action, Adventure, Drama          8.8        92.0
# 13           UA      179   Action, Adventure, Drama          8.7        87.0
# ..          ...      ...                        ...          ...         ...
# 405          UA      124  Animation, Action, Sci-Fi          8.0         NaN
# 410          UA      107             Action, Sci-Fi          8.0        84.0
# 426           U      112          Adventure, Sci-Fi          8.0        79.0
# 431           A       99     Action, Drama, Western          8.0        65.0
# 436      Passed      141     Action, Drama, Western          8.0        93.0
#
#                   Director                  Star1  No_of_Votes        Gross
# 2        Christopher Nolan         Christian Bale      2303232  534858444.0
# 5            Peter Jackson            Elijah Wood      1642758  377845905.0
# 8        Christopher Nolan      Leonardo DiCaprio      2067042  292576195.0
# 10           Peter Jackson            Elijah Wood      1661481  315544750.0
# 13           Peter Jackson            Elijah Wood      1485555  342551365.0
# ..                     ...                    ...          ...          ...
# 405        Katsuhiro Ôtomo           Mitsuo Iwata       164918     553171.0
# 410          James Cameron  Arnold Schwarzenegger       799795   38400000.0
# 426  Franklin J. Schaffner        Charlton Heston       165167   33395426.0
# 431           Sergio Leone         Clint Eastwood       198219   14500000.0
# 436           Howard Hawks             John Wayne        56305   12535000.0
#
# [82 rows x 11 columns]

# %% [markdown]
# ### **Question 34**
# Year 2010 se 2020 ke darmiyan release hone wali un movies ka data filter karein jinko Certificate 'UA' ya 'A' mila hai.

# %%
Dataset = Dataset2[
    (Dataset2['Released_Year'].between(2010, 2020)) & 
    (Dataset2['Certificate'].isin(['UA', 'A']))]
Dataset
# Out:
#                        Series_Title  Released_Year Certificate  Runtime  \
# 8                         Inception           2010          UA      148
# 19                     Gisaengchung           2019           A      132
# 21                     Interstellar           2014          UA      169
# 33                            Joker           2019           A      122
# 34                         Whiplash           2014           A      106
# ..                              ...            ...         ...      ...
# 898  Dawn of the Planet of the Apes           2014          UA      130
# 900                    Serbuan maut           2011           A      101
# 901                    End of Watch           2012           A      109
# 903                  A Star Is Born           2018          UA      136
# 908                        Kick-Ass           2010          UA      117
#
#                          Genre  IMDB_Rating  Meta_score           Director  \
# 8    Action, Adventure, Sci-Fi          8.8        74.0  Christopher Nolan
# 19     Comedy, Drama, Thriller          8.6        96.0       Bong Joon Ho
# 21    Adventure, Drama, Sci-Fi          8.6        74.0  Christopher Nolan
# 33      Crime, Drama, Thriller          8.5        59.0      Todd Phillips
# 34                Drama, Music          8.5        88.0    Damien Chazelle
# ..                         ...          ...         ...                ...
# 898   Action, Adventure, Drama          7.6        79.0        Matt Reeves
# 900           Action, Thriller          7.6        73.0       Gareth Evans
# 901       Action, Crime, Drama          7.6        68.0         David Ayer
# 903      Drama, Music, Romance          7.6        88.0     Bradley Cooper
# 908      Action, Comedy, Crime          7.6        66.0     Matthew Vaughn
#
#                     Star1  No_of_Votes        Gross
# 8       Leonardo DiCaprio      2067042  292576195.0
# 19           Kang-ho Song       552778   53367844.0
# 21    Matthew McConaughey      1512360  188020017.0
# 33        Joaquin Phoenix       939252  335451311.0
# 34           Miles Teller       717585   13092000.0
# ..                    ...          ...          ...
# 898           Gary Oldman       411599  208545589.0
# 900             Iko Uwais       190531    4105123.0
# 901       Jake Gyllenhaal       228132   41003371.0
# 903             Lady Gaga       334312  215288866.0
# 908  Aaron Taylor-Johnson       524081   48071303.0
#
# [119 rows x 11 columns]

# %% [markdown]
# ### **Question 35**
# Dataset mein 'Meta_score' 90 se zyada aur 'IMDB_Rating' 8.5 se kam wali unique movies kaunsi hain?

# %%
movies = Dataset2[(Dataset2['Meta_score'] > 90) & (Dataset2['IMDB_Rating'] < 8.5)]
movies['Series_Title'].unique().tolist()
movies
# Out:
#                                           Series_Title  Released_Year  \
# 66                                              WALL·E           2008
# 74                                      Apocalypse Now           1979
# 78   Dr. Strangelove or: How I Learned to Stop Worr...           1964
# 81                                         Rear Window           1954
# 89                             Jodaeiye Nader az Simin           2011
# ..                                                 ...            ...
# 873                                  The African Queen           1951
# 875                                           Fantasia           1940
# 881                                The Florida Project           2017
# 895                                           Leviafan           2014
# 994                                 A Hard Day's Night           1964
#
#     Certificate  Runtime                         Genre  IMDB_Rating  \
# 66            U       98  Animation, Adventure, Family          8.4
# 74            R      147           Drama, Mystery, War          8.4
# 78            A       95                        Comedy          8.4
# 81            U      112             Mystery, Thriller          8.4
# 89        PG-13      123                         Drama          8.3
# ..          ...      ...                           ...          ...
# 873          PG      105     Adventure, Drama, Romance          7.7
# 875           G      125    Animation, Family, Fantasy          7.7
# 881           A      111                         Drama          7.6
# 895           R      140                  Crime, Drama          7.6
# 994           U       87        Comedy, Music, Musical          7.6
#
#      Meta_score              Director                Star1  No_of_Votes  \
# 66         95.0        Andrew Stanton            Ben Burtt       999790
# 74         94.0  Francis Ford Coppola         Martin Sheen       606398
# 78         97.0       Stanley Kubrick        Peter Sellers       450474
# 81        100.0      Alfred Hitchcock        James Stewart       444074
# 89         95.0        Asghar Farhadi         Payman Maadi       220002
# ..          ...                   ...                  ...          ...
# 873        91.0           John Huston      Humphrey Bogart        71481
# 875        96.0           James Algar     Samuel Armstrong        88662
# 881        92.0            Sean Baker     Brooklynn Prince        95181
# 895        92.0    Andrey Zvyagintsev  Aleksey Serebryakov        49397
# 994        96.0        Richard Lester          John Lennon        40351
#
#            Gross
# 66   223808164.0
# 74    83471511.0
# 78      275902.0
# 81    36764313.0
# 89     7098492.0
# ..           ...
# 873     536118.0
# 875   76408097.0
# 881    5904366.0
# 895    1092800.0
# 994   13780024.0
#
# [94 rows x 11 columns]

# %% [markdown]
# ### **Question 36**
# (Visualization) 'Drama' aur 'Action' genres ki movies ke 'Gross' revenue ko compare karne ke liye ek Grouped Box Plot ya Violin Plot banayein.

# %%
Dataset2['Gross'] = pd.to_numeric(Dataset2['Gross'], errors='coerce')
Dataset = Dataset2[Dataset2['Genre'].str.contains('Drama|Action', na=False)]
Dataset.boxplot(column='Gross', by='Genre')
# Out:
# <Axes: title={'center': 'Gross'}, xlabel='Genre'>

# %% [markdown]
# ### **Question 37**
# Har Director ki un movies ka count maloom karein jinhone 'No_of_Votes' 500,000 (5 lakh) se zyada hasil kiye hain.

# %%
# Filter aur count karein
Dataset = Dataset2[Dataset2['No_of_Votes'] > 500000]
directors = Dataset['Director'].value_counts()
directors
# Out:
# Director
# Christopher Nolan    8
# Quentin Tarantino    8
# Steven Spielberg     8
# Peter Jackson        5
# David Fincher        5
#                     ..
# Richard Marquand     1
# Brian De Palma       1
# Mel Gibson           1
# Gus Van Sant         1
# Chris Columbus       1
# Name: count, Length: 107, dtype: int64

# %% [markdown]
# ### **Question 38**
# Un movies ke naam aur ratings batayein jinka 'Released_Year' 2000 se pehle ka hai AUR unka 'Gross' unke overall median gross se zyada hai.

# %%
# Median nikalen aur filter karen
gross = Dataset2['Gross'].median()
Released_Year = Dataset2[(Dataset2['Released_Year'] < 2000) & (Dataset2['Gross'] > gross)]
Released_Year[['Series_Title', 'Released_Year', 'IMDB_Rating']]
# Out:
#                            Series_Title  Released_Year  IMDB_Rating
# 0              The Shawshank Redemption           1994          9.3
# 1                         The Godfather           1972          9.2
# 3                The Godfather: Part II           1974          9.0
# 6                          Pulp Fiction           1994          8.9
# 7                      Schindler's List           1993          8.9
# ..                                  ...            ...          ...
# 985                Escape from Alcatraz           1979          7.6
# 987                    Midnight Express           1978          7.6
# 988  Close Encounters of the Third Kind           1977          7.6
# 992                     The Jungle Book           1967          7.6
# 997               From Here to Eternity           1953          7.6
#
# [186 rows x 3 columns]

# %% [markdown]
# ### **Question 39**
# Aisi movies ka data nikalein jahan 'Star1' (Main Actor) aur 'Director' dono bilkul same person hain.

# %%
same_person = Dataset2[Dataset2['Star1'] == Dataset2['Director']]
same_person[['Series_Title', 'Star1', 'Director']]
# Out:
#                               Series_Title                  Star1  \
# 26                         La vita è bella        Roberto Benigni
# 51                            Modern Times        Charles Chaplin
# 52                             City Lights        Charles Chaplin
# 83                      The Great Dictator        Charles Chaplin
# 102                             Braveheart             Mel Gibson
# 124                           Citizen Kane           Orson Welles
# 127                                The Kid        Charles Chaplin
# 167                             Unforgiven         Clint Eastwood
# 193                          The Gold Rush        Charles Chaplin
# 194                           Sherlock Jr.          Buster Keaton
# 225                            Gran Torino         Clint Eastwood
# 371  Bom Yeoareum Gaeul Gyeoul Geurigo Bom             Ki-duk Kim
# 391                            Sling Blade     Billy Bob Thornton
# 402                     Dances with Wolves          Kevin Costner
# 414                             Annie Hall            Woody Allen
# 530                     This Is Spinal Tap             Rob Reiner
# 533                              Manhattan            Woody Allen
# 537                     La montaña sagrada   Alejandro Jodorowsky
# 653                                Hana-bi         Takeshi Kitano
# 664                           A Bronx Tale         Robert De Niro
# 691                 The Outlaw Josey Wales         Clint Eastwood
# 753                                   Argo            Ben Affleck
# 776                                Kung fu           Stephen Chow
# 794              Hedwig and the Angry Inch  John Cameron Mitchell
# 799     South Park: Bigger, Longer & Uncut            Trey Parker
# 812                                 Hamlet        Kenneth Branagh
# 837                                  Zelig            Woody Allen
# 845                           Le locataire         Roman Polanski
# 965          The Bridges of Madison County         Clint Eastwood
#
#                   Director
# 26         Roberto Benigni
# 51         Charles Chaplin
# 52         Charles Chaplin
# 83         Charles Chaplin
# 102             Mel Gibson
# 124           Orson Welles
# 127        Charles Chaplin
# 167         Clint Eastwood
# 193        Charles Chaplin
# 194          Buster Keaton
# 225         Clint Eastwood
# 371             Ki-duk Kim
# 391     Billy Bob Thornton
# 402          Kevin Costner
# 414            Woody Allen
# 530             Rob Reiner
# 533            Woody Allen
# 537   Alejandro Jodorowsky
# 653         Takeshi Kitano
# 664         Robert De Niro
# 691         Clint Eastwood
# 753            Ben Affleck
# 776           Stephen Chow
# 794  John Cameron Mitchell
# 799            Trey Parker
# 812        Kenneth Branagh
# 837            Woody Allen
# 845         Roman Polanski
# 965         Clint Eastwood

# %% [markdown]
# ### **Question 40**
# (Visualization) Top 5 highest rated movies aur unke 'Meta_score' vs 'IMDB_Rating' (scaled to 100) ka ek Side-by-Side Comparison Bar Chart banayein.

# %%
import matplotlib.pyplot as plt
top5 = Dataset2.nlargest(5, 'IMDB_Rating').copy()
top5['IMDB_x10'] = top5['IMDB_Rating'] * 10
top5.plot(x='Series_Title', y=['IMDB_x10', 'Meta_score'], kind='bar')
plt.show()
